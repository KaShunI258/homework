# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

V23F = pd.read_csv('team_scores_23F.csv')
VNL_outcomes23 = pd.read_csv('team_scores_23Tfinal.csv')
V22F = pd.read_csv('team_scores_22F.csv')
VNL_outcomes22 = pd.read_csv('team_scores_22Tfinal.csv')
V21F = pd.read_csv('team_scores_21F.csv')
VNL_outcomes21 = pd.read_csv('team_scores_21Tfinal.csv')

Vfeature23DF = pd.read_csv('featuring_2023.csv')
Vfeature22DF = pd.read_csv('featuring_2022.csv')
Vfeature21DF = pd.read_csv('featuring_2021.csv')
print(Vfeature23DF)
# Out:
#     Unnamed: 0 Country  Ranking_scores  Attack_avg  Block_avg  Serve_avg  \
# 0            0     CRO       -1.508183   14.524793   2.665289   1.115702
# 1            1     BRA       11.606792   11.027397   1.894977   1.392694
# 2            2     BUL        3.649122   13.070175   2.960526   0.899123
# 3            3     CAN       10.547279   14.111498   2.195122   0.993031
# 4            4     CHN       18.819318   11.105263   2.184211   0.894737
# 5            5     DOM        4.049494   13.873518   2.648221   0.968379
# 6            6     GER       19.809281   13.706564   2.220077   1.486486
# 7            7     ITA       20.120638   14.003831   2.873563   0.957854
# 8            8     JPN       11.411693   14.453441   1.882591   1.336032
# 9            9     KOR      -10.380414   11.102564   1.282051   1.076923
# 10          10     NED        7.746449   13.744292   2.694064   1.232877
# 11          11     POL       28.304062   14.891697   2.851986   1.064982
# ...

# %%
# 2023各国attack的能力对比
country_name = Vfeature23DF['Country']
xwidth = 0.6
bars = plt.bar(country_name,Vfeature23DF.Attack_avg)

plt.xticks(country_name, rotation=60)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=7)
plt.title('the Attack Ability of 2023 Participating Countries', fontsize=16)
plt.xlabel('participants')
plt.ylabel('ability')
plt.ylim(bottom=9)
plt.show()

# %%
# 2023各国Error频次对比
country_name = Vfeature23DF['Country']
xwidth = 0.6
bars = plt.bar(country_name,Vfeature23DF.Error_avg)

plt.xticks(country_name, rotation=60)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=7)
plt.title('the Error Probability of 2023 Participating Countries', fontsize=16)
plt.xlabel('participants')
plt.ylabel('probability')
plt.ylim(bottom=4)
plt.show()

# %%
# 画散点图
attack_avg = Vfeature23DF['Attack_avg'].append(Vfeature22DF['Attack_avg'])
attack_avg = attack_avg.append(Vfeature21DF['Attack_avg'])
error_avg = Vfeature23DF['Error_avg'].append(Vfeature22DF['Error_avg']) 
error_avg = error_avg.append(Vfeature21DF['Error_avg'])
plt.scatter(attack_avg, error_avg, color='green', alpha=1)

# 添加标题和标签
plt.title('Scatter Plot of Attack_avg vs Error_avg')
plt.xlabel('Attack_avg')
plt.ylabel('Error_avg')

# 显示图形
plt.show()
# Out:
# C:\Users\hjw\AppData\Local\Temp\ipykernel_19164\4068128616.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   attack_avg = Vfeature23DF['Attack_avg'].append(Vfeature22DF['Attack_avg'])
# C:\Users\hjw\AppData\Local\Temp\ipykernel_19164\4068128616.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   attack_avg = attack_avg.append(Vfeature21DF['Attack_avg'])
# C:\Users\hjw\AppData\Local\Temp\ipykernel_19164\4068128616.py:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   error_avg = Vfeature23DF['Error_avg'].append(Vfeature22DF['Error_avg'])
# ...

# %%
# 画散点图
rep_avg = Vfeature23DF['Reception_avg'].append(Vfeature22DF['Reception_avg'])
rep_avg = attack_avg.append(Vfeature21DF['Reception_avg'])
dig_avg = Vfeature23DF['Dig_avg'].append(Vfeature22DF['Dig_avg']) 
dig_avg = error_avg.append(Vfeature21DF['Dig_avg'])
plt.scatter(rep_avg, dig_avg, color='red', alpha=1)

# 添加标题和标签
plt.title('Scatter Plot of Attack_avg vs Error_avg')
plt.xlabel('Reception_avg')
plt.ylabel('Dig_avg')

# 显示图形
plt.show()
# Out:
# C:\Users\hjw\AppData\Local\Temp\ipykernel_19164\4167380854.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rep_avg = Vfeature23DF['Reception_avg'].append(Vfeature22DF['Reception_avg'])
# C:\Users\hjw\AppData\Local\Temp\ipykernel_19164\4167380854.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rep_avg = attack_avg.append(Vfeature21DF['Reception_avg'])
# C:\Users\hjw\AppData\Local\Temp\ipykernel_19164\4167380854.py:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dig_avg = Vfeature23DF['Dig_avg'].append(Vfeature22DF['Dig_avg'])
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

V23F = pd.read_csv('team_scores_23F.csv')
VNL_outcomes23 = pd.read_csv('team_scores_23Tfinal.csv')
V22F = pd.read_csv('team_scores_22F.csv')
VNL_outcomes22 = pd.read_csv('team_scores_22Tfinal.csv')
V21F = pd.read_csv('team_scores_21F.csv')
VNL_outcomes21 = pd.read_csv('team_scores_21Tfinal.csv')

Vfeature23DF = pd.read_csv('featuring_2023.csv')
Vfeature22DF = pd.read_csv('featuring_2022.csv')
Vfeature21DF = pd.read_csv('featuring_2021.csv')
# 提取数据
country_name23 = ['CRO', 'BRA', 'BUL', 'CAN', 'CHN', 'DOM', 'GER', 'ITA', 'JPN',
                'KOR', 'NED', 'POL', 'SRB', 'THA', 'TUR', 'USA']

# 设置图形大小和布局
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(15, 15))
fig.tight_layout(pad=4.0)

# 初始化计数器
i = 0

# 遍历国家
for row in axes:
    for ax in row:
        # 提取数据
        bel_data = V23F[V23F['Country'] == country_name23[i]]
        
        # 提取指标和对应的数值
        labels = ['OH', 'MB', 'OP']
        values = bel_data[labels].iloc[0]

        # 画饼图
        ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue', 'lightgreen'])

        # 添加标题
        ax.set_title(country_name23[i])

        # 更新计数器
        i += 1

# 添加图例
fig.legend(labels=labels, loc="upper right")

# 显示图形
plt.show()
plt.savefig('pies.png')

# %%
# 示例数据
country_name_main = ['BRA', 'CAN', 'CHN', 'DOM', 'GER', 'ITA', 'JPN', 'KOR', 'NED', 'POL', 'SRB', 'THA', 'TUR', 'USA']
rank_21 = Vfeature21DF['Ranking_scores'].drop([1,3])
rank_22 = Vfeature22DF['Ranking_scores'].drop([1,3])
rank_23 = Vfeature23DF['Ranking_scores'].drop([2,5])
print(len(rank_21),len(rank_22),len(rank_23))

# 设置图形大小
plt.figure(figsize=(10, 8))

# 设置条形图位置
bar_width = 0.25
bar_positions_21 = np.arange(len(country_name_main))
bar_positions_22 = bar_positions_21 + bar_width
bar_positions_23 = bar_positions_21 + 2 * bar_width

# 绘制条形图
plt.barh(bar_positions_21, rank_21, height=bar_width, label='2021', color='lightcoral', edgecolor='black')
plt.barh(bar_positions_22, rank_22, height=bar_width, label='2022', color='lightblue', edgecolor='black')
plt.barh(bar_positions_23, rank_23, height=bar_width, label='2023', color='lightgreen', edgecolor='black')

# 在条形的顶部添加数值标签（保留一位小数）
for i, v in enumerate(rank_21):
    plt.text(v, i - 0.1, '{:.1f}'.format(v), color='black', fontweight='bold')

for i, v in enumerate(rank_22):
    plt.text(v, i + bar_width - 0.1, '{:.1f}'.format(v), color='black', fontweight='bold')

for i, v in enumerate(rank_23):
    plt.text(v, i + 2 * bar_width - 0.1, '{:.1f}'.format(v), color='black', fontweight='bold')

# 设置刻度标签
plt.yticks(bar_positions_21 + bar_width, country_name_main)

# 去除坐标轴框架
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# 添加水平网格线
plt.grid(axis='x', linestyle='--', alpha=0.6)

# 添加标题和标签
plt.title('Ranking Scores for Each Country (2021-2023)')
plt.xlabel('Ranking Scores')
plt.ylabel('Country')

# 调整图例位置
plt.legend(loc='upper right')

# 显示图形
plt.show()
# Out:
# 14 14 14

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 从文件中读取数据
filepath = 'Final_features.csv'
df = pd.read_csv(filepath)

# 选择特征向量
features = df[['attack_scores', 'attack_errors', 'block_effective', 'block_errors',
               'dig_succeeded', 'dig_errors', 'reception_succeeded', 'reception_errors',
               'serve_scores', 'serve_errors', 'win_or_lose']]

# 计算特征之间的相关性矩阵
correlation_matrix = features.corr()

# 使用Seaborn绘制热力图
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.3f', linewidths=.5)
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# 从文件中读取数据
filepath = 'Final_features.csv'
df = pd.read_csv(filepath)

# 选择特征向量
features = df[['attack_scores', 'attack_errors', 'block_effective', 'block_errors',
               'dig_succeeded', 'dig_errors', 'reception_succeeded', 'reception_errors',
               'serve_scores', 'serve_errors']]

# 初始化 T-SNE 模型
tsne = TSNE(random_state=42)

# 使用 T-SNE 进行降维
features_tsne = tsne.fit_transform(features)

# 创建 DataFrame 以方便绘图
df_tsne = pd.DataFrame(features_tsne, columns=['Dimension 1', 'Dimension 2'])

# 添加 'win_or_lose' 列以区分不同类别
df_tsne['win_or_lose'] = df['win_or_lose']

# 使用 Seaborn 绘制散点图
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Dimension 1', y='Dimension 2', hue='win_or_lose', data=df_tsne, palette='viridis')
plt.title('T-SNE Visualization of Features')
plt.show()
# Out:
# D:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# 假设 df 是你的数据框
# 计算新特征
df['attack_efficiency'] = df['attack_scores'] / (df['attack_errors'] + df['attack_errors'])
df['block_efficiency'] = df['block_effective'] / (df['block_errors'] + df['block_effective'])
df['serve_efficiency'] = df['serve_scores'] / (df['serve_errors'] + df['serve_scores'])

# 提取新特征向量
features2 = df[['attack_efficiency', 'block_efficiency', 'serve_efficiency']]

# 设置画布大小
plt.figure(figsize=(12, 8))

# 使用 seaborn 的 boxplot 函数画盒须图
sns.boxplot(data=features2, orient='h')

# 添加标题和标签
plt.title('Box-and-Whisker Plot of New Features')
plt.xlabel('Feature Values')

# 显示图表
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
filepath = 'Final_features.csv'
df = pd.read_csv(filepath)

feature_columns = ['attack_scores', 'attack_errors', 'block_effective', 'block_errors',
                   'dig_succeeded', 'dig_errors', 'reception_succeeded', 'reception_errors',
                   'serve_scores', 'serve_errors', 'set_efficiency']

df = df.dropna()

# print(df)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

X_train = train_df[feature_columns]

X_test = test_df[feature_columns]

# 训练集的标签
y_train = train_df['win_or_lose']

# 测试集的标签
y_test = test_df['win_or_lose']

# 数据标准化
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 创建一个SVM分类器
clf = SVC(probability=True)

param_grid_svm = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'poly', 'rbf'],
    'gamma': ['scale', 'auto']
}
grid_search_svm = GridSearchCV(clf, param_grid_svm, cv=3)
grid_search_svm.fit(X_train_scaled, y_train)
best_params_svm = grid_search_svm.best_params_

# print(best_params_svm)
#  {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}

best_clf = grid_search_svm.best_estimator_
best_clf.fit(X_train_scaled, y_train)

# 11. 在测试集上进行预测
y_pred = best_clf.predict(X_test_scaled)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("SVM:")
print("Best Parameters:", best_params_svm)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

import seaborn as sns
cv_results = pd.DataFrame(grid_search_svm.cv_results_)[['param_C', 'param_kernel', 'param_gamma', 'mean_test_score']]
pivot_table = cv_results.pivot_table(index=['param_kernel', 'param_C'], columns='param_gamma', values='mean_test_score')

# 可视化参数网格搜索过程
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', cbar=True)
plt.title('GridSearchCV - Mean Test Score for Each Parameter Combination')
plt.tight_layout()
plt.show()
# Out:
# SVM:
# Best Parameters: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Accuracy: 0.8386243386243386
# Confusion Matrix:
#  [[151  38]
#  [ 23 166]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.80      0.83       189
#          1.0       0.81      0.88      0.84       189
#
#     accuracy                           0.84       378
#    macro avg       0.84      0.84      0.84       378
# weighted avg       0.84      0.84      0.84       378

# %%
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
import seaborn as sns
import matplotlib.pyplot as plt

filepath = 'Final_features.csv'
df = pd.read_csv(filepath)

feature_columns = ['attack_scores', 'attack_errors', 'block_effective', 'block_errors',
                   'dig_succeeded', 'dig_errors', 'reception_succeeded', 'reception_errors',
                   'serve_scores', 'serve_errors', 'set_efficiency']

df = df.dropna()

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

X_train = train_df[feature_columns]
X_test = test_df[feature_columns]

y_train = train_df['win_or_lose']
y_test = test_df['win_or_lose']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 创建一个逻辑回归模型
logreg_model = LogisticRegression()

param_grid_logreg = {
    'C': [0.1, 1, 10],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear']
}

grid_search_logreg = GridSearchCV(logreg_model, param_grid_logreg, cv=3)
grid_search_logreg.fit(X_train_scaled, y_train)
best_params_logreg = grid_search_logreg.best_params_

best_logreg_model = grid_search_logreg.best_estimator_
best_logreg_model.fit(X_train_scaled, y_train)

# 在测试集上进行预测
y_pred = best_logreg_model.predict(X_test_scaled)

# 计算其他评估指标
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Logistic Regression:")
print("Best Parameters:", best_params_logreg)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# 可视化参数网格搜索过程
cv_results = pd.DataFrame(grid_search_logreg.cv_results_)[['param_C', 'param_penalty', 'mean_test_score']]
pivot_table = cv_results.pivot_table(index=['param_penalty', 'param_C'], values='mean_test_score')

plt.figure(figsize=(8, 4))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', cbar=True)
plt.title('GridSearchCV - Mean Test Score for Each Parameter Combination')
plt.tight_layout()
plt.show()
# Out:
# Logistic Regression:
# Best Parameters: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Accuracy: 0.828042328042328
# Confusion Matrix:
#  [[146  43]
#  [ 22 167]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.77      0.82       189
#          1.0       0.80      0.88      0.84       189
#
#     accuracy                           0.83       378
#    macro avg       0.83      0.83      0.83       378
# weighted avg       0.83      0.83      0.83       378

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

filepath = 'Final_features.csv'

# 读取数据集
df = pd.read_csv(filepath)

# 处理缺失值
df = df.dropna(subset=['win_or_lose'])

# 选择特征和目标变量
features = df[['attack_scores', 'attack_errors', 'block_effective', 'block_errors',
               'dig_succeeded', 'dig_errors', 'reception_succeeded', 'reception_errors',
               'serve_scores', 'serve_errors']]
target = df['win_or_lose']

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# 标准化
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 创建随机森林分类器
rf_classifier = RandomForestClassifier()

# 设置网格搜索参数
param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# 执行网格搜索
grid_search_rf = GridSearchCV(rf_classifier, param_grid_rf, cv=3)
grid_search_rf.fit(X_train_scaled, y_train)

# 获取最佳模型和参数
best_rf_model = grid_search_rf.best_estimator_
best_params_rf = grid_search_rf.best_params_

# 在测试集上进行预测
y_pred = best_rf_model.predict(X_test_scaled)

# 计算准确率
accuracy = accuracy_score(y_test, y_pred)

# 计算其他评估指标
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Random Forest Classifier:")
print("Best Parameters:", best_params_rf)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# 可视化参数网格搜索过程
cv_results = pd.DataFrame(grid_search_rf.cv_results_)[['param_n_estimators', 'param_max_depth', 'param_min_samples_split', 'param_min_samples_leaf', 'mean_test_score']]
pivot_table = cv_results.pivot_table(index=['param_max_depth', 'param_min_samples_split'], columns=['param_n_estimators', 'param_min_samples_leaf'], values='mean_test_score')

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', cbar=True)
plt.title('GridSearchCV - Mean Test Score for Each Parameter Combination')
plt.tight_layout()
plt.show()
# Out:
# Random Forest Classifier:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy: 0.8047493403693932
# Confusion Matrix:
#  [[150  42]
#  [ 32 155]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.78      0.80       192
#          1.0       0.79      0.83      0.81       187
#
#     accuracy                           0.80       379
#    macro avg       0.81      0.81      0.80       379
# weighted avg       0.81      0.80      0.80       379

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

filepath = 'Final_features.csv'

# 读取数据集
df = pd.read_csv(filepath)

# 处理缺失值
df = df.dropna(subset=['win_or_lose'])

# 选择特征和目标变量
features = df[['attack_scores', 'attack_errors', 'block_effective', 'block_errors',
               'dig_succeeded', 'dig_errors', 'reception_succeeded', 'reception_errors',
               'serve_scores', 'serve_errors']]
target = df['win_or_lose']

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# 标准化
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 创建K最近邻分类器
knn_classifier = KNeighborsClassifier()

# 设置网格搜索参数
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

# 执行网格搜索
grid_search_knn = GridSearchCV(knn_classifier, param_grid_knn, cv=3)
grid_search_knn.fit(X_train_scaled, y_train)

# 获取最佳模型和参数
best_knn_model = grid_search_knn.best_estimator_
best_params_knn = grid_search_knn.best_params_

# 在测试集上进行预测
y_pred = best_knn_model.predict(X_test_scaled)

# 计算准确率
accuracy = accuracy_score(y_test, y_pred)

# 计算其他评估指标
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("K-Nearest Neighbors Classifier:")
print("Best Parameters:", best_params_knn)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)

# 可视化参数网格搜索过程
cv_results = pd.DataFrame(grid_search_knn.cv_results_)[['param_n_neighbors', 'param_weights', 'param_p', 'mean_test_score']]
pivot_table = cv_results.pivot_table(index=['param_weights', 'param_n_neighbors'], columns='param_p', values='mean_test_score')

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', cbar=True)
plt.title('GridSearchCV - Mean Test Score for Each Parameter Combination')
plt.tight_layout()
plt.show()
# Out:
# D:\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc, f1_score, recall_score, precision_score
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 读取数据集
filepath = 'Final_features.csv'
df = pd.read_csv(filepath)

# 处理缺失值
df = df.dropna(subset=['win_or_lose'])

# 选择特征和目标变量
features = df[['attack_scores', 'attack_errors', 'block_effective', 'block_errors',
               'dig_succeeded', 'dig_errors', 'reception_succeeded', 'reception_errors',
               'serve_scores', 'serve_errors']]
target = df['win_or_lose']

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# 标准化
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 初始化模型
svm_model = SVC(probability=True)
logreg_model = LogisticRegression()
rf_model = RandomForestClassifier()
knn_model = KNeighborsClassifier()

# 训练模型
svm_model.fit(X_train_scaled, y_train)
logreg_model.fit(X_train_scaled, y_train)
rf_model.fit(X_train_scaled, y_train)
knn_model.fit(X_train_scaled, y_train)

# 获取每个模型的预测概率
y_prob_svm = svm_model.predict_proba(X_test_scaled)[:, 1]
y_prob_logreg = logreg_model.predict_proba(X_test_scaled)[:, 1]
y_prob_rf = rf_model.predict_proba(X_test_scaled)[:, 1]
y_prob_knn = knn_model.predict_proba(X_test_scaled)[:, 1]

# 计算 ROC 曲线和 AUC
fpr_svm, tpr_svm, _ = roc_curve(y_test, y_prob_svm)
roc_auc_svm = auc(fpr_svm, tpr_svm)

fpr_logreg, tpr_logreg, _ = roc_curve(y_test, y_prob_logreg)
roc_auc_logreg = auc(fpr_logreg, tpr_logreg)

fpr_rf, tpr_rf, _ = roc_curve(y_test, y_prob_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)

fpr_knn, tpr_knn, _ = roc_curve(y_test, y_prob_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)

# 绘制 ROC 曲线
plt.figure(figsize=(10, 6))
plt.plot(fpr_svm, tpr_svm, label=f'SVM (AUC = {roc_auc_svm:.3f})')
plt.plot(fpr_logreg, tpr_logreg, label=f'Logistic Regression (AUC = {roc_auc_logreg:.3f})')
plt.plot(fpr_rf, tpr_rf, label=f'Random Forest (AUC = {roc_auc_rf:.3f})')
plt.plot(fpr_knn, tpr_knn, label=f'K-Nearest Neighbors (AUC = {roc_auc_knn:.3f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Recall)')
plt.legend()
plt.show()
